# %%
#reading the file
import pandas as pd
data = pd.read_csv("Worldpopulationbycountries.csv")
data
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54208.0      55434.0
# 1    Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                    Afghanistan          AFG    8996967.0    9169406.0
# 3     Africa Western and Central          AFW   96396419.0   98407221.0
# 4                         Angola          AGO    5454938.0    5531451.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX     947000.0     966000.0
# 262                  Yemen, Rep.          YEM    5315351.0    5393034.0
# 263                 South Africa          ZAF   17099836.0   17524533.0
# 264                       Zambia          ZMB    3070780.0    3164330.0
# 265                     Zimbabwe          ZWE    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
#visualize the dataset
import matplotlib.pyplot as plt 
import pandas as pd
data = pd.read_csv("Worldpopulationbycountries.csv", header = 0 , index_col = 0)
data
# Out:
#                             Country Code         1960         1961  \
# Country Name
# Aruba                                ABW      54208.0      55434.0
# Africa Eastern and Southern          AFE  130836765.0  134159786.0
# Afghanistan                          AFG    8996967.0    9169406.0
# Africa Western and Central           AFW   96396419.0   98407221.0
# Angola                               AGO    5454938.0    5531451.0
# ...                                  ...          ...          ...
# Kosovo                               XKX     947000.0     966000.0
# Yemen, Rep.                          YEM    5315351.0    5393034.0
# South Africa                         ZAF   17099836.0   17524533.0
# Zambia                               ZMB    3070780.0    3164330.0
# Zimbabwe                             ZWE    3776679.0    3905038.0
#
#                                     1962         1963         1964  \
# Country Name
# ...

# %%
plt.hist(data['1960'])
# Out:
# (array([241.,   6.,   7.,   5.,   0.,   0.,   2.,   2.,   0.,   1.]),
#  array([2.83300000e+03, 3.03218157e+08, 6.06433480e+08, 9.09648804e+08,
#         1.21286413e+09, 1.51607945e+09, 1.81929478e+09, 2.12251010e+09,
#         2.42572542e+09, 2.72894075e+09, 3.03215607e+09]),
#  <BarContainer object of 10 artists>)

# %%
#second vizualization
data.plot()
# Out:
# <AxesSubplot:xlabel='Country Name'>

# %%
#exploring the dataset
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172174e+08  1.187633e+08  1.208717e+08  1.234910e+08  1.261315e+08
# std    3.695745e+08  3.739180e+08  3.804316e+08  3.889142e+08  3.974401e+08
# min    2.833000e+03  3.077000e+03  3.367000e+03  3.703000e+03  4.063000e+03
# 25%    5.022802e+05  5.109642e+05  5.206540e+05  5.311622e+05  5.421252e+05
# 50%    3.718330e+06  3.826398e+06  3.929109e+06  4.015834e+06  4.124521e+06
# 75%    2.636053e+07  2.721235e+07  2.808607e+07  2.890669e+07  2.972333e+07
# max    3.032156e+09  3.071596e+09  3.124561e+09  3.189656e+09  3.255146e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.288372e+08  1.316853e+08  1.345256e+08  1.374350e+08  1.404490e+08
# ...

# %%
#boxplot
# %matplotlib notebook
data.plot.box(data["2000"])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
#Checking for correlation
corr = data.corr
corr
# Out:
# <bound method DataFrame.corr of                             Country Code         1960         1961  \
# Country Name
# Aruba                                ABW      54208.0      55434.0
# Africa Eastern and Southern          AFE  130836765.0  134159786.0
# Afghanistan                          AFG    8996967.0    9169406.0
# Africa Western and Central           AFW   96396419.0   98407221.0
# Angola                               AGO    5454938.0    5531451.0
# ...                                  ...          ...          ...
# Kosovo                               XKX     947000.0     966000.0
# Yemen, Rep.                          YEM    5315351.0    5393034.0
# South Africa                         ZAF   17099836.0   17524533.0
# Zambia                               ZMB    3070780.0    3164330.0
# Zimbabwe                             ZWE    3776679.0    3905038.0
#
#                                     1962         1963         1964  \
# Country Name
# ...

# %%
#this kind of dataset doesn't allow us to see if there is a corelation or not
